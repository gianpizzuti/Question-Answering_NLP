# %%
 from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive/My Drive/NLP_progetto_2024
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).
# /gdrive/My Drive/NLP_progetto_2024

# %%
#Installing gensim
#!pip install --upgrade gensim

# %% [markdown]
# Here to import useful libraries

# %%
import json
import pandas as pd
import numpy as np
import re
from tqdm import tqdm
from gensim.models.word2vec import Word2Vec

# %% [markdown]
# ## 1) Preprocess Data

# %%
# Load the dataset
file_json = open("medical_meadow_wikidoc_medical_flashcards.json")
data = json.load(file_json)

# %%
# Converting the json file to a pandas dataframe
pd_dataset = pd.DataFrame.from_dict(data)
# Explore the dataframe
print(pd_dataset.head())
print(pd_dataset.columns)
pd_dataset.describe()
# Out:
#                        instruction  \
# 0  Answer this question truthfully
# 1  Answer this question truthfully
# 2  Answer this question truthfully
# 3  Answer this question truthfully
# 4  Answer this question truthfully
#
#                                                input  \
# 0  What is the relationship between very low Mg2+...
# 1  What leads to genitourinary syndrome of menopa...
# 2  What does low REM sleep latency and experienci...
# 3  What are some possible causes of low PTH and h...
# 4  How does the level of anti-müllerian hormone r...
#
#                                               output
# 0  Very low Mg2+ levels correspond to low PTH lev...
# 1  Low estradiol production leads to genitourinar...
# 2  Low REM sleep latency and experiencing halluci...
# 3  PTH-independent hypercalcemia, which can be ca...
# 4  The level of anti-müllerian hormone is directl...
# Index(['instruction', 'input', 'output'], dtype='object')
#                             instruction  input output
# count                             33955  33955  33955
# unique                                1  33289  33335
# top     Answer this question truthfully
# freq                              33955    408    402

# %%
# We observe that the column "instruction" has only one unique value, so we are going to drop it
pd_dataset = pd_dataset.drop(columns=['instruction'])

# %%
# Split the dataset into two different dataframes, one for questions and one for answers
pd_dataset_questions = pd_dataset['input']
pd_dataset_answers = pd_dataset['output']

# %%
# Convert the dataframe to a numpy array
np_dataset_answers = pd_dataset_answers.to_numpy().flatten()
np_dataset_questions = pd_dataset_questions.to_numpy().flatten()

# %%
# Tokenize the answers dataset
np_dataset_answers_tokens = [re.sub('\W', ' ', sentence).lower().split() for sentence in np_dataset_answers]

# %%
print(np_dataset_answers_tokens[7])
# Out:
# ['insulinoma', 'or', 'sulfonylurea', 'drugs', 'can', 'cause', 'low', 'glucose', 'and', 'high', 'c', 'peptide', 'levels']

# %%
# We remove only ',' and '.' since other symbols may be useful (like + for chemical formulations) and lower case
final_dataset_tokens = [re.sub(r'[.,()]', '', str(sentence)).lower() for w in np_dataset_answers_tokens for sentence in w]

# %%
print(final_dataset_tokens[12])
# Out:
# results

# %%
# We encode 'utf-8' all the tokens
# Necessary to train Word2Vec
final_encoded = [s.encode('utf-8').split() for s in final_dataset_tokens]

# %%
print(final_encoded[23])
# Out:
# [b'syndrome']

# %% [markdown]
# We are not removing stopwords right now since we are going to do word2vec
# Now we have our dataset, we are going to work on the word2vec implementation

# %%
word2vec = Word2Vec(final_encoded, vector_size=50, min_count=10, window=20)

# %%
len(word2vec.wv)
# Out:
# 8721

# %%
# Visualize the vector for the word 'blood'
term = 'blood'
word2vec.wv[term.encode('utf-8')]
#  (b'subperiosteal', 0.4164178967475891),
#  (b'right', 0.41351082921028137),
#  (b'weakens', 0.41124093532562256)]

# %%
import random

# Select 500 random samples
sample = random.sample(list(word2vec.wv.key_to_index), 500)
sample_decoded = []
for s in sample:
  sample_decoded.append(s.decode('utf-8'))

# %%
word_vectors = word2vec.wv[sample]
word_vectors
# Out:
# array([[ 0.01303462,  0.00832977, -0.01951368, ..., -0.01242318,
#          0.00497906, -0.00171659],
#        [-0.00693002,  0.00723173,  0.00424167, ..., -0.00481276,
#          0.01101673,  0.01202074],
#        [ 0.01263914, -0.01871311,  0.01410609, ...,  0.01615741,
#         -0.01637337,  0.01876849],
#        ...,
#        [-0.01896856,  0.01443628,  0.01813582, ..., -0.00124633,
#          0.0017246 , -0.00249093],
#        [-0.00190813, -0.00689055,  0.01365748, ...,  0.00874928,
#          0.01238842,  0.00601917],
#        [-0.01941793,  0.01155131,  0.01036901, ...,  0.01717287,
#          0.0033099 ,  0.00465026]], dtype=float32)

# %%
from sklearn.manifold import TSNE

tsne = TSNE(n_components=3, n_iter=2000)

tsne_embedding = tsne.fit_transform(word_vectors)

# %%
x, y, z = np.transpose(tsne_embedding)

# %%
#!pip install plotly
# Out:
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (5.15.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly) (8.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly) (24.0)

# %%
import plotly.express as px

# Visualize the samples extracted before
fig = px.scatter_3d(x=x, y=y, z=z)
fig.update_traces(marker=dict(size=3,line=dict(width=2)))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="bbb147e0-44b6-4cdd-9651-461d2a8a6cf9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bbb147e0-44b6-4cdd-9651-461d2a8a6cf9")) {                    Plotly.newPlot(                        "bbb147e0-44b6-4cdd-9651-461d2a8a6cf9",                        [{"hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003ez=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle","line":{"width":2},"size":3},"mode":"markers","name":"","scene":"scene","showlegend":false,"x":[13.4749755859375,10.773530006408691,-10.30026912689209,8.577502250671387,22.026704788208008,-32.58595275878906,-24.222957611083984,8.198486328125,-8.319173812866211,29.175464630126953,4.630187511444092,-17.526649475097656,-35.77376174926758,-18.641799926757812,-20.470726013183594,11.785029411315918,12.516968727111816,16.022233963012695,7.121085166931152,-9.53448486328125,8.664813995361328,20.495641708374023,-15.777944564819336,32.78973388671875,22.36485481262207,13.059488296508789,-6.103076934814453,11.88017749786377,-19.612483978271484,15.8909273147583,8.478943824768066,-8.358197212219238,20.968509674072266,-33.13822937011719,-35.803585052490234,1.9467759132385254,-19.166423797607422,-13.577316284179688,-37.05924606323242,-2.3015570640563965,32.70536804199219,-47.7126579284668,-37.247161865234375,30.95029640197754,37.064762115478516,25.782703399658203,28.72603416442871,36.31679153442383,-28.599510192871094,-46.51093673706055,10.883605003356934,-1.8349721431732178,-23.075008392333984,-30.567916870117188,-32.298954010009766,46.12369155883789,27.42608642578125,20.92738151550293,-32.58083724975586,33.60823440551758,22.297977447509766,34.40154266357422,30.68851089477539,23.359344482421875,24.576725006103516,-34.108680725097656,7.586209297180176,2.779175281524658,-1.2390999794006348,9.302759170532227,-8.464235305786133,-43.17079162597656,-31.3356990814209,29.487607955932617,-7.055217266082764,-5.222512722015381,-10.577347755432129,-6.54233455657959,15.0977783203125,-5.343935012817383,-6.859411239624023,12.010897636413574,-15.34825325012207,31.663637161254883,9.799202919006348,
","slowed","nonallergic","poliovirus","anticoagulation","say","cuts","share","viscosity","episodes","blindness","branchial","plant","patchy","bradykinesia","crohn","terbinafine","translocation","myocardium","papilledema","basilar","grown","imposed","finding","hemoglobin","ht","although","lentiginous","contribute","creutzfeldt","microdeletion","intraabdominal","dizziness","layers","genitalia","thyrotoxicosis","diffusion","ball","u","cardioversion","therapeutic","macrocytic","c1","examination","starling","juvenile","termination","anticoagulants","condition","immobilization","agent","preventing","myosin","treat","mp","turner","choanal","neuropathic","drink","dependent","apolipoproteins","iso","hepatoduodenal","ketoacid","supplementation","h1","vomit","handle","blocked","ovulatory","stellate","you","balloon","test","carry","shiga","methionine"],"x":[13.4749755859375,10.773530006408691,-10.30026912689209,8.577502250671387,22.026704788208008,-32.58595275878906,-24.222957611083984,8.198486328125,-8.319173812866211,29.175464630126953,4.630187511444092,-17.526649475097656,-35.77376174926758,-18.641799926757812,-20.470726013183594,11.785029411315918,12.516968727111816,16.022233963012695,7.121085166931152,-9.53448486328125,8.664813995361328,20.495641708374023,-15.777944564819336,32.78973388671875,22.36485481262207,13.059488296508789,-6.103076934814453,11.88017749786377,-19.612483978271484,15.8909273147583,8.478943824768066,-8.358197212219238,20.968509674072266,-33.13822937011719,-35.803585052490234,1.9467759132385254,-19.166423797607422,-13.577316284179688,-37.05924606323242,-2.3015570640563965,32.70536804199219,-47.7126579284668,-37.247161865234375,30.95029640197754,37.064762115478516,25.782703399658203,28.726034164428 ...

# %%
# Add some specific terms to sample:
words = ['blood', 'heart']
words_encoded = []
for w in words:
  words_encoded.append(w.encode('utf-8'))

word_vectors = word2vec.wv[words_encoded+sample]

tsne = TSNE(n_components=3)
tsne_embedding = tsne.fit_transform(word_vectors)

x, y, z = np.transpose(tsne_embedding)

# %%
import plotly.express as px

# Visualize the position of the terms specified before

r = (-200,200)
fig = px.scatter_3d(x=x, y=y, z=z, range_x=r, range_y=r, range_z=r, text=words + [None] * 500)
fig.update_traces(marker=dict(size=3,line=dict(width=2)),textfont_size=10)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="e6e143ff-3143-4e47-8a0e-c47aecdf2b5e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e6e143ff-3143-4e47-8a0e-c47aecdf2b5e")) {                    Plotly.newPlot(                        "e6e143ff-3143-4e47-8a0e-c47aecdf2b5e",                        [{"hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003ez=%{z}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle","line":{"width":2},"size":3},"mode":"markers+text","name":"","scene":"scene","showlegend":false,"text":["blood","heart",null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null],"x":[50.380882263183594,-7.184550762176514,-24.068538665771484,23.067890167236328,-19.72372055053711,21.905202865600586,-12.652911186218262,4.0876851081848145,-0.288555383682251,-0.8954079151153564,37.9561653137207,37.40550231933594,20.969812393188477,26.795705795288086,-12.32222843170166,-12.346637725830078,17.5181884765625,10.258636474609375,36.842308044433594,24.755794525146484,14.7142972946167,-30.056474685668945,-4.345065116882324,10.38044261932373,-14.2434720993042,-16.683853149414062,24.926191329956055,6.292691707611084,36.78361129760742,26.239439010620117,-16.8689022064209,29.05226707458496,13.79266738891 ...

# %% [markdown]
# ## References
#
#
# *   Tutorials of Natural Language Processing course (A.Y. 2023/2024) at PoliMi
